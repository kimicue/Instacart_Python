# %% [markdown]
# # Importing Libraries and Data

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Assign target data to 'path' and verify

path = r'/Users/peterkim/Document/sql/CareerFoundry/Immersion Prep/4. Python Fundamentals for Data Analysts/Instacart Basket Analysis'
path
# Out:
# '/Users/peterkim/Document/sql/CareerFoundry/Immersion Prep/4. Python Fundamentals for Data Analysts/Instacart Basket Analysis'

# %% [markdown]
# # 3. Import the 'orders_products_combined' from the pickle

# %%
# Importing dataframe, 'orders_products_combined.pkl' into 'ords_prods_comb'

ords_prods_comb = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# # 4. Check the shape of the imported dataframe

# %%
# Checking 'ords_prods_comb'
ords_prods_comb
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2539329        1    prior             1          2
# 2          2539329        1    prior             1          2
# 3          2539329        1    prior             1          2
# 4          2539329        1    prior             1          2
# ...            ...      ...      ...           ...        ...
# 32434484   2977660   206209    prior            13          1
# 32434485   2977660   206209    prior            13          1
# 32434486   2977660   206209    prior            13          1
# 32434487   2977660   206209    prior            13          1
# 32434488   2977660   206209    prior            13          1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# ...

# %% [markdown]
# # 5. Combine the 'orders_products_combined' dataframe with your wrangled, cleaned, and deduped products dataset

# %%
# Checking dimension of 'ords_prods_comb'

ords_prods_comb.shape
# Out:
# (32434489, 11)

# %%
# Importing dataframe, 'products_clean.csv'

prods_clean = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_clean.csv'), index_col = False)

# %%
# Checking prods_clean

prods_clean
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49688       49688       49684
# 49689       49689       49685
# 49690       49690       49686
# 49691       49691       49687
# 49692       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49688          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
# Merging two dataframes ('df_merged' and 'ords_prods_comb') using unique key variable 'product_id'

df_merged = ords_prods_comb.merge(prods_clean, on = 'product_id')

# %%
# Checking df_merged

df_merged
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2398795        1    prior             2          3
# 2           473747        1    prior             3          3
# 3          2254736        1    prior             4          4
# 4           431534        1    prior             5          4
# ...            ...      ...      ...           ...        ...
# 32434207   1320836   202557    prior            17          2
# 32434208     31526   202557    prior            18          5
# 32434209    758936   203436    prior             1          2
# 32434210   2745165   203436    prior             2          3
# 32434211   3093936   205420    prior             1          4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# ...

# %%
# Checking demension of 'df_merged'

df_merged.shape
# Out:
# (32434212, 16)

# %%
# Making new “_merge” column (also referred to as a “merge flag")

df_merged['_merge'].value_counts()
# Out:
# _merge
# both          32434212
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# # 7. Export the newly created dataframe as 'orders_products_merged'

# %%
# Exporting new merged file as 'ordered_products_merged.pkl'

df_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ordered_products_merged.pkl'))
