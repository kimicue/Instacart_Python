# %% [markdown]
# # Importing Libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Data

# %%
# Importing 'order.csv' from the project folder path as 'df_ords'

df_ords = pd.read_csv(r'/Users/peterkim/Document/sql/CareerFoundry/Immersion Prep/4. Python Fundamentals for Data Analysts/Instacart Basket Analysis/02 Data/Original Data/orders.csv', index_col=False)

# %% [markdown]
# # Simplfying the path to data and re-importing

# %%
# Assigning the project folder path to a variable 'path'

path = r'/Users/peterkim/Document/sql/CareerFoundry/Immersion Prep/4. Python Fundamentals for Data Analysts/Instacart Basket Analysis'

# %%
path
# Out:
# '/Users/peterkim/Document/sql/CareerFoundry/Immersion Prep/4. Python Fundamentals for Data Analysts/Instacart Basket Analysis'

# %%
# Re-import 'order.csv' using 'path', a simplified path from target data to 'df_ords'

df_ords = pd.read_csv(os.path.join(path,'02 Data','Original Data','orders.csv'), index_col=False)

# %%
# Import 'order.csv' using 'path' from target data to 'df_prods'

df_prods = pd.read_csv(os.path.join(path,'02 Data','Original Data','products.csv'), index_col=False)

# %% [markdown]
# # 1. Perform the wrangling procedures you walked through in this Exercise.

# %% [markdown]
# ## Dropping 'eval_set' column

# %%
# Dropping eval_set column from orders.csv

df_ords.drop(columns = ['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
# Assigning the dataset 'orders.csv' without 'eval_set' column to a variable 'df.ords'

df_ords = df_ords.drop(columns = ['eval_set'])

# %% [markdown]
# ## Renaming

# %%
# Renaming the column 'order_dow' to 'order_day_of_week' and allow overwrite the original column name with the new column name

df_ords.rename(columns = {'order_dow' : 'order_day_of_week'}, inplace = True)

# %% [markdown]
# ## Data type changing

# %%
# Changing the data type of the "order_id" column from a number to a string

df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
# Getting the data type of new 'order_id' as 'O' which stands for object, pandas' version of the string

df_ords['order_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## Importing dataset using 'path', a simplified path from target data to 'df_dep'

# %%
# Importing data set 'departments.csv'

df_dep = pd.read_csv(os.path.join(path,'02 Data','Original Data','departments.csv'), index_col=False)

# %%
# Showing that 'departments.csv' has 1 row and 22 columns

df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %% [markdown]
# ## Transposing

# %%
# Transposing df_dep

df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Assigning transposed version of dataframe to a variable 'df_dep_t'

df_dep_t = df_dep.T

# %%
# Checking 'df_dep_t'

df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Displaying index column

df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %% [markdown]
# ## Taking the header, the first row

# %%
# Take the first row of df_dep_t for the header

new_header = df_dep_t.iloc[0]

# %%
# Displaying header, the first row

new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# Take the data under the header row for a new df

df_dep_t_new = df_dep_t[1:]

# %%
# Showing old dataframe without the first row

df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
# Set the header row as the df header
# new_header = df_dep_t.iloc[0]

df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# ## Data dictionary

# %%
# Turn 'df_dep_t_new' dataframe into a dictionary

data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# ## Subsetting

# %%
# Checking 'department_id' 19, department 'snack'

print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %%
# Showing which rows are fall under 'department_id' 19

df_prods['department_id']==19
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %%
df_prods[df_prods['department_id']==19]
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
# Assigning the 'df_snacks' from the result being a list of only those values within df_prods that have a "department_id" of 19

df_snacks = df_prods[df_prods['department_id']==19]

# %%
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %% [markdown]
# # 2. Find another identifier in the 'df_ords' and change it to a suitable format.

# %%
# Checking the table overall

df_ords
# Out:
#         order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0        2539329        1             1                  2                  8
# 1        2398795        1             2                  3                  7
# 2         473747        1             3                  3                 12
# 3        2254736        1             4                  4                  7
# 4         431534        1             5                  4                 15
# ...          ...      ...           ...                ...                ...
# 3421078  2266710   206209            10                  5                 18
# 3421079  1854736   206209            11                  4                 10
# 3421080   626363   206209            12                  1                 12
# 3421081  2977660   206209            13                  1                 12
# 3421082   272231   206209            14                  6                 14
#
#          days_since_prior_order
# ...

# %%
# Checking the data types of all columns

df_ords.dtypes
# Out:
# order_id                   object
# user_id                     int64
# order_number                int64
# order_day_of_week           int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
# Changing the data type of 'user_id' from int64 to object (string)

df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
df_ords['user_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# # 3. Look for a variable in 'df_ords'  with an unintuitive name and change its name without overwriting the dataframe.

# %%
# Changing variable 'order_number' to 'number_of_orders'

df_ords.rename(columns = {'order_number':'number_of_orders'}, inplace = True)

# %%
df_ords.head()
# Out:
#   order_id user_id  number_of_orders  order_day_of_week  order_hour_of_day  \
# 0  2539329       1                 1                  2                  8
# 1  2398795       1                 2                  3                  7
# 2   473747       1                 3                  3                 12
# 3  2254736       1                 4                  4                  7
# 4   431534       1                 5                  4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# ## 4. Find the busiest hour for placing orders, frequency of the corresponding variable

# %%
# Print all the functions within a column 'order_hour_of_day' with no missing values
# The busiest hour is for placing orders is 10:00 AM

df_ords['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %% [markdown]
# # 5. The meaning behind a value of 4 in the "department_id" within the 'df_prods' using a data dictionary.

# %%
# 'produce' is the meaning behind a value of 4 in the "department_id" within the 'df_pods'

print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %% [markdown]
# # 6. Create a subset containing only the required information, about breakfast item sales.

# %%
# Finding 'department_id' for 'breakfast'
# 14 is 'department_id' for 'breakfast'

df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Assigning the 'df_breakfast' from the result being a list of only those values within df_prods that have a "department_id" of 14

df_breakfast = df_prods.loc[df_prods['department_id'] == 14]

# %%
df_breakfast
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %% [markdown]
# # 7. Find all observations include items from the departments; alcohol, deli, beverages, and meat/seafood.

# %%
# Assigning the 'df_breakfast' from the result being a list of only those values within df_prods that have a "department_id" of 14

df_dinner = df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]

# %%
df_dinner.head(20)
# Out:
#     product_id                                       product_name  aisle_id  \
# 2            3               Robust Golden Unsweetened Oolong Tea        94
# 6            7                     Pure Coconut Water With Orange        98
# 9           10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                                  Peach Mango Juice        31
# 16          17                                  Rendered Duck Fat        35
# 19          20     Pomegranate Cranberry & Aloe Vera Enrich Drink        98
# 22          23                             Organic Turkey Burgers        49
# 34          35     Italian Herb Porcini Mushrooms Chicken Sausage       106
# 38          39           Daily Tangerine Citrus Flavored Beverage        64
# 39          40  Beef Hot Links Beef Smoked Sausage With Chile ...       106
# 43          44                        Sparkling Raspberry Seltzer       115
# ...

# %% [markdown]
# # 8. How many rows and columns does the last dataframe you created have?

# %%
# There are 7650 rows and 5 columns

df_dinner.shape
# Out:
# (7650, 5)

# %% [markdown]
# # 9. Extract all the information you can about the customer with a "user_id" of “1”

# %%
# Assigning the 'df_ords_user01' from the result being a list of only those values within df_ords that have a "user_id" of '1'

df_ords_user01 = df_ords[df_ords['user_id'] == '1']

# %%
df_ords_user01
# Out:
#    order_id user_id  number_of_orders  order_day_of_week  order_hour_of_day  \
# 0   2539329       1                 1                  2                  8
# 1   2398795       1                 2                  3                  7
# 2    473747       1                 3                  3                 12
# 3   2254736       1                 4                  4                  7
# 4    431534       1                 5                  4                 15
# 5   3367565       1                 6                  2                  7
# 6    550135       1                 7                  1                  9
# 7   3108588       1                 8                  1                 14
# 8   2295261       1                 9                  1                 16
# 9   2550362       1                10                  4                  8
# 10  1187899       1                11                  4                  8
#
#     days_since_prior_order
# 0                      NaN
# ...

# %% [markdown]
# # 10. Basic stats of 'user01' based on the information

# %%
df_ords_user01.describe()
# Out:
#        number_of_orders  order_day_of_week  order_hour_of_day  \
# count         11.000000          11.000000          11.000000
# mean           6.000000           2.636364          10.090909
# std            3.316625           1.286291           3.477198
# min            1.000000           1.000000           7.000000
# 25%            3.500000           1.500000           7.500000
# 50%            6.000000           3.000000           8.000000
# 75%            8.500000           4.000000          13.000000
# max           11.000000           4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %% [markdown]
# # 11. Check the organization, structure, section headings, and code comments.
#
# Okay!

# %% [markdown]
# # 12. Export 'df_ords' as “orders_wrangled.csv” in “Prepared Data” folder

# %%
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))

# %% [markdown]
# # 13. Export 'df_dep_t_new' as “departments_wrangled.csv” in “Prepared Data” folder

# %%
df_dep_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'))
